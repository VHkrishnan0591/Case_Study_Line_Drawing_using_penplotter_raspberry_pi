# %%
from PIL import Image

# %%
img = Image.open("D:\\EMBEDDED PRESENTATION\\Case_Study_Line_Drawing_using_penplotter_raspberry_pi\\artifacts\\upload_images\\cat_image.jpg")

# %%
if img:
    print("yes")
# Out:
# yes

# %%
import cv2

# %%
img = cv2.imread("D:\\EMBEDDED PRESENTATION\\Case_Study_Line_Drawing_using_penplotter_raspberry_pi\\artifacts\\upload_images\\cat_image.jpg")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)
